# %%
print("hii python")
# Out:
# hii python

# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3

# %%
a=1
b=2
c=a+b
print("c")
# Out:
# c

# %%
n=int(input("enter the number 1:"))
m=int(input("enter the number 2:"))
z=n+m
print(z)
# Out:
# enter the number 1: 121
# enter the number 2: 141
# 262

# %%
a='ram'
b=19
print("my name is",a, "years old",b)
# Out:
# my name is ram years old 19

# %%
# comments
# import pyjokes
# j=pyjokes.get_joke()
# print(j)

# %%
6+3
# Out:
# 9

# %%
6+9*4-8/6
# Out:
# 40.666666666666664

# %%
9*7*8/8-6+3.3
# Out:
# 60.3

# %%
print('hii hii')
# Out:
# hii hii

# %%
# to print multi line use ''' or """
print('''hii hellow
hii hellow
hii hellow''')
# Out:
# hii
# hii
# hii

# %%
a='ram'
b='raj'
print(a+b)
# Out:
# ramraj

# %%
# type of function
n=90.0
print(type(n))
# Out:
# <class 'float'>

# %%
n='hii'
print(type(n))
# Out:
# <class 'str'>

# %%
# chapter 2.1 variable
a=1
b=3
print(a+b)
# Out:
# 4

# %%
# chapter 2.2 data type
a= 9 #type int
b= 20000.2 #type float
c='string' #type string
d=True #type boolean
e=None #type none
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# chapter 2.3 rules of variable
a=3 #valid
bbbb=2 #valid
ram=1 #valid
ram@=1 #invalid

# %%
# chapter 2.4 oparaters
a=5
a+=8
print(a) #update value of a
b=3
b-=2
print(b)
# Out:
# 13
# 1

# %%
# chapterv 2.5 type function
# changing type of variable
a="2.09"
print(type(a))
b=float(a)
print(type(b))
# here we changed the type of variable from str to float
# Out:
# <class 'str'>
# <class 'float'>

# %%
# chpater 2.6 user input
n=input("enter the number 1:")
m=int(input("enter the number 2:"))
z=n+m
print(z)
# Out:
# enter the number 1: 2
# enter the number 2: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 n=input("enter the number 1:")
#       3 m=int(input("enter the number 2:"))
# ----> 4 z=n+m
#       5 print(z)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# without using data type 
# here is understsnd that it is a string 
# so string cocatition will accour
a=input("enter num 1: ")
b=input("enter num 2: ")
print("The sum is",a+b)
# Out:
# enter num 1:  23
# enter num 2:  03
# The sum is 2303

# %%
# with using data type int
a=int(input("enter num 1: "))
b=int(input("enter num 2: "))
print("The sum is:",a+b)
# Out:
# enter num 1:  23
# enter num 2:  03
# The sum is: 26

# %%
# practice questions
a=23
z=int(input("enter z : "))
b=a%z
print("the remainder is ",b)
# Out:
# enter z :  2
# the remainder is  1

# %%
# comparision operater
a=34
b=80
a>=b
# Out:
# False

# %%
a=12
c=23
d=34
avg=(a+c+d)/3
print(avg)
# Out:
# 23.0

# %%
n=int(input("enter the number :"))
sq=n**2 #or n*n
print("the square of num is  :",sq)
# Out:
# enter the number : 3
# the square of num is  : 9

# %%
x = 5  # Assigning an integer value to the variable x
y = "Hello"# Assigning a string value to the variable y
print("here we asscen the value for x,y")
# Out:
# here we asscen the value for x,y

# %%
age = 25
name = "John"
is_student = True
