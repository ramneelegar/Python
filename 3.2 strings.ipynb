# %%
# some maths functions
import numpy as np
print(abs(-14))
print(pow(2,3))
print(np.log(10))
print(np.sqrt(25))
# Out:
# 14
# 8
# 2.302585092994046
# 5.0

# %%
# practice questions
# display user name fallowed by gm

a=str(input('enter name'))
print('Good Mrg',a)

print(f"Good mrg {a}")
# Out:
# enter name ram
# Good Mrg ram
# Good mrg ram

# %%
a="hii \"ram\" this python is nice"
print(a)
# Out:
# hii "ram" this python is nice

# %%
# replacement
a='''dear name
     you r selected
     date'''
print(a.replace('name','ramu').replace('date','03 may'))
# Out:
# dear ramu
#      you r selected
#      03 may

# %%
# find doublr qout n replace by single qout
a='hii i m  ram'
print(a.find('  '))

print(a.replace('  ',' and raj '))
# Out:
# 7
# hii i m and raj ram
