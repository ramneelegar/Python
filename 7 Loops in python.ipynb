# %%
# printing 1 to 6 numbera using while loop
i=1
while(i<6):
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# printing hii 3 times
count=0
while(count<3):
    count+=1
    print('hii')
# Out:
# hii
# hii
# hii

# %%
# write a program to print the content of the list
l=['hii',1,2.0,'snpsu','ram']
i=0
while(i<len(l)):
    print(l[i])
    i+=1
# Out:
# hii
# 1
# 2.0
# snpsu
# ram

# %%
# for loop in list
l=[1,2,'ram']
for i in l:
    print(i)
# Out:
# 1
# 2
# ram

# %% [markdown]
# ##### for loop i  tuple
# t=(1,2.5,3)
# for i in t:
#     print(i)

# %%
# for loop in string
s='ram'
for i in s:
    print(i)
# Out:
# r
# a
# m

# %%
# in for loop we can also specify thr start stop n step size
for i in range(0,44,4):#(start,stop,step_size)
    print(i)
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
# for loop with else 
# it will also print else statement
l=[1,2,3]
for i in l:
    print(i)
else:
    print('done')
# Out:
# 1
# 2
# 3
# done

# %%
# break statement
for i in range(6):
    if(i==4):
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
# continue statement
for i in range(8):
    if(i==5):
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7

# %%
# pass statement
for i in range(5):
    pass #if we don't write pass it will show errer

i=0
while(i<5):
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# practice sheet
n=int(input("enter no. that table u want to print"))

for j in range(10):   #j is iterations
    print(n*j)
# Out:
# enter no. that table u want to print 5
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %%
n=int(input("enter n:"))
for i in range(1,11):
    print(f"{n}X{i}={n*i}")
# Out:
# enter n: 5
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
# 5X10=50

# %%
l=["sam","ram","akash"]
for i in l:
    if(i.startswith('s')):
        print(f"hello {i}")
# Out:
# hello sam

# %%
l=["sam","ram","akash"]
for i in l:
    if(i.endswith('m')):
        print(f"hello {i}")
# Out:
# hello sam
# hello ram

# %%
n=int(input("enter the number:"))
i=1
while(i<11):
    print(f"{n}X{i}={n*i}")
    i+=1
# Out:
# enter the number: 5
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
# 5X10=50

# %%
# tables reverse order
n=int(input("enter n:"))
for i in range(1,11):
    print(f"{n}X{11-i}={n*(11-i)}")
# Out:
# enter n: 5
# 5X10=50
# 5X9=45
# 5X8=40
# 5X7=35
# 5X6=30
# 5X5=25
# 5X4=20
# 5X3=15
# 5X2=10
# 5X1=5

# %%
n=int(input("enter the number:"))
for i in range(2,n):
    if(n%i==0):
        print("the number is not prime")
        break;
else:
    print(" the number is prime ")
# Out:
# enter the number: 25
# the number is not prime

# %%
# sum of n numbers
n=int(input("enter the number:"))
i=1
sum=0
while(i<=n):
    sum += i
    i+=1

print(sum)
# Out:
# enter the number: 5
# 15

# %%
n=int(input("enter the number:"))
i=0
sum=0
for i in range(n+1):
    sum+=i
    i+=1

print(sum)
# Out:
# enter the number: 5
# 15

# %%
n=int(input("enter the number:"))
fac=1
for i in range(1,n+1):
    fac=fac*i

print(f"the factorial of {n} is {fac}")
# Out:
# enter the number: 5
# the factorial of 5 is 120

# %%
n=int(input("enter the number:"))
for i in range(1,n+1):
    print(" "*(n-i),end="")
    print("*"*(2*i-1),end="")
    print("")
# Out:
# enter the number: 3
#   *
#  ***
# *****

# %%
n=int(input("enter the number:"))
for i in range(1,n+1):
    print("*"*i,end="")
    print("")
# Out:
# enter the number: 3
# *
# **
# ***

# %%
n=int(input("enter the number:"))
for i in range(1,n+1):
   if(i==1 or i==n):
       print("*"*n,end="")
   else:
       print("*",end="")
       print(" "* (n-2),end="")
       print('*',end='')
   print('')
# Out:
# enter the number: 7
# *******
# *     *
# *     *
# *     *
# *     *
# *     *
# *******
