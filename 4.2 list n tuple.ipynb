# %%
# write a program to store 4 fruits in a list by user
fruits=[]
a=input('enter the fruit:')
fruits.append(a)
# here append is impto add in list 

b=input('enter the fruit:')
fruits.append(b)

c=input('enter the fruit:')
fruits.append(c)

d=input('enter the fruit:')
fruits.append(d)

print(fruits)
# Out:
# enter the fruit: apple
# enter the fruit: banana
# enter the fruit: grapes
# enter the fruit: mango
# ['apple', 'banana', 'grapes', 'mango']

# %%
# marks of 4 students in asccending order
marks=[]
m1=int(input("enter the marks :"))
marks.append(m1)

m2=int(input("enter the marks :"))
marks.append(m2)

m3=int(input("enter the marks :"))
marks.append(m3)

m4=int(input("enter the marks :"))
marks.append(m4)

marks.sort()  # sort for asscending order
print(marks)
# Out:
# enter the marks : 10
# enter the marks : 50
# enter the marks : 87
# enter the marks : 56
# [10, 50, 56, 87]

# %%
# show tuple type cannot change in python
tuple=("apple",1.2,34,"sharan")
tuple[0]='hii'
print(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # show tuple type cannot change in python
#       2 tuple=("apple",1.2,34,"sharan")
# ----> 3 tuple[0]='hii'
#       4 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# sum of elements in the list
a=[1,23,43,56,7,9]
print(sum(a))
# Out:
# 139

# %%
# count no. of 0's in the tuple
a=(1,0,0,2,0,3,0)
print(a.count(0))
# Out:
# 4
